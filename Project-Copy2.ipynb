# %% [markdown]
# # Part 1: Data Preprocessing

# %%
import numpy as np
import pandas as pd
import math
import geopandas as gpd
import bs4
import re
import requests
import os
import pyarrow.parquet as pq
import glob

# %% [markdown]
# ### Uber Data

# %%
uber_rides_sample = pd.read_csv("uber_rides_sample.csv", index_col = 0)
uber_rides_sample.head()
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 24238194    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06 UTC
# 27835199    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56 UTC
# 44984355   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00 UTC
# 25894730    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21 UTC
# 17610152  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 24238194        -73.999817        40.738354         -73.999512
# 27835199        -73.994355        40.728225         -73.994710
# 44984355        -74.005043        40.740770         -73.962565
# 25894730        -73.976124        40.790844         -73.965316
# 17610152        -73.925023        40.744085         -73.973082
#
#           dropoff_latitude  passenger_count
# 24238194         40.723217                1
# 27835199         40.750325                1
# 44984355         40.772647                1
# 25894730         40.803349                3
# 17610152         40.761247                5

# %%
uber_rides_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 24238194 to 11951496
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  object
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.7+ MB

# %% [markdown]
# ### Download Yellow Taxi Data and get a sample dataset with its size close to Uber Dataset

# %%
# result = set()
# for filename in os.listdir("./yellow_taxi"):
#     if filename.endswith(".parquet"):
#         existing_columns = set(pq.ParquetFile("./yellow_taxi/"+filename).schema.names)
#         result = result.union(existing_columns)

# result

# %%
# Get Yellow Taxi Parquet files
def download_yellow_taxi_parquet_files():
    response = requests.get("https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page")
    soup = bs4.BeautifulSoup(response.content, 'html.parser')
    yellow_records = soup.find_all("a", attrs={"title": "Yellow Taxi Trip Records"})
    if not os.path.exists("./yellow_taxi"):
        os.makedirs("./yellow_taxi")
    
    for record in yellow_records:
        pattern = r'yellow_tripdata_(2009|201[0-5])-\d{2}\.'
        link = record["href"]
        if re.search(pattern, link):
            filename = os.path.join("yellow_taxi", link.split("/")[-1])
            response = requests.get(link)
            
            with open(filename, "wb") as f:
                f.write(response.content)

# %%
"""
Comment the line below if no need to download the Yellow Taxi Parquet files.
"""

# download_yellow_taxi_parquet_files()
# Out:
# '\nComment the line below if no need to download the Yellow Taxi Parquet files.\n'

# %%
# Get Yellow Taxi Data sample
def generate_yellow_taxi_df():
    columns_to_select = ['DOLocationID',
                         'End_Lat',
                         'End_Lon',
                         'PULocationID',
                         'Passenger_Count',
                         'Start_Lat',
                         'Start_Lon',
                         'Total_Amt',
                         'Trip_Distance',
                         'Trip_Dropoff_DateTime',
                         'Trip_Pickup_DateTime',
                         'dropoff_datetime',
                         'dropoff_latitude',
                         'dropoff_longitude',
                         'passenger_count',
                         'pickup_datetime',
                         'pickup_latitude',
                         'pickup_longitude',
                         'total_amount',
                         'tpep_dropoff_datetime',
                         'tpep_pickup_datetime',
                         'trip_distance',
                         'Tip_Amt',
                         'tip_amount']

    directory = "./yellow_taxi"
    yellow_taix_df = pd.DataFrame()
    for filename in os.listdir(directory):
        if filename.endswith(".parquet"):
            existing_columns = set(pq.ParquetFile("./yellow_taxi/"+filename).schema.names)
            columns_to_read = list(set(columns_to_select) & existing_columns)
            table = pq.read_table("./yellow_taxi/"+filename, columns=columns_to_read)
            df = table.to_pandas()
            random_subset = df.sample(n=3000)
            yellow_taix_df = pd.concat([yellow_taix_df, random_subset], ignore_index=True)
    yellow_taix_df.to_csv("yellow_taxi_ride_sample.csv", index = False)

# %%
"""
Comment the line below if the Yellow Taxi Data sample already generated.
"""

generate_yellow_taxi_df()

# %%
yellow_taxi_ride_sample = pd.read_csv("yellow_taxi_ride_sample.csv")
yellow_taxi_ride_sample.head()
# Out:
#    DOLocationID  PULocationID  trip_distance  tip_amount tpep_pickup_datetime  \
# 0         141.0         113.0           4.32         0.0  2011-07-08 23:15:00
# 1         162.0          48.0           1.40         0.0  2011-07-20 19:22:24
# 2         237.0         237.0           0.85         1.5  2011-07-26 18:18:00
# 3         237.0          79.0           3.00         0.0  2011-07-01 21:33:28
# 4         114.0         261.0           1.87         2.0  2011-07-02 16:04:00
#
#    passenger_count  total_amount tpep_dropoff_datetime  End_Lon  \
# 0              5.0          15.9   2011-07-08 23:37:00      NaN
# 1              1.0           8.8   2011-07-20 19:32:33      NaN
# 2              1.0           8.3   2011-07-26 18:24:00      NaN
# 3              1.0          10.7   2011-07-01 21:44:42      NaN
# 4              1.0           9.8   2011-07-02 16:13:00      NaN
#
#   Trip_Pickup_DateTime  ...  End_Lat  Total_Amt  Trip_Dropoff_DateTime  \
# 0                  NaN  ...      NaN        NaN                    NaN
# 1                  NaN  ...      NaN        NaN                    NaN
# 2                  NaN  ...      NaN        NaN                    NaN
# 3                  NaN  ...      NaN        NaN                    NaN
# 4                  NaN  ...      NaN        NaN                    NaN
#
#    Tip_Amt  pickup_longitude  pickup_datetime dropoff_datetime  \
# 0      NaN               NaN              NaN              NaN
# 1      NaN               NaN              NaN              NaN
# 2      NaN               NaN              NaN              NaN
# 3      NaN               NaN              NaN              NaN
# 4      NaN               NaN              NaN              NaN
#
#    pickup_latitude  dropoff_longitude dropoff_latitude
# 0              NaN                NaN              NaN
# 1              NaN                NaN              NaN
# 2              NaN                NaN              NaN
# 3              NaN                NaN              NaN
# 4              NaN                NaN              NaN
#
# [5 rows x 24 columns]

# %%
yellow_taxi_ride_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DOLocationID           180000 non-null  float64
#  1   PULocationID           180000 non-null  float64
#  2   trip_distance          216000 non-null  float64
#  3   tip_amount             216000 non-null  float64
#  4   tpep_pickup_datetime   180000 non-null  object
#  5   passenger_count        216000 non-null  float64
#  6   total_amount           216000 non-null  float64
#  7   tpep_dropoff_datetime  180000 non-null  object
#  8   End_Lon                36000 non-null   float64
#  9   Trip_Pickup_DateTime   36000 non-null   object
#  10  Trip_Distance          36000 non-null   float64
#  11  Passenger_Count        36000 non-null   float64
#  12  Start_Lat              36000 non-null   float64
#  13  Start_Lon              36000 non-null   float64
#  14  End_Lat                36000 non-null   float64
#  15  Total_Amt              36000 non-null   float64
#  16  Trip_Dropoff_DateTime  36000 non-null   object
#  17  Tip_Amt                36000 non-null   float64
#  18  pickup_longitude       36000 non-null   float64
#  19  pickup_datetime        36000 non-null   object
#  20  dropoff_datetime       36000 non-null   object
#  21  pickup_latitude        36000 non-null   float64
#  22  dropoff_longitude      36000 non-null   float64
#  23  dropoff_latitude       36000 non-null   float64
# dtypes: float64(18), object(6)
# memory usage: 46.1+ MB

# %% [markdown]
# ### Data Preprocessing - Yellow Taxi Data
# #### Combine columns with the same thing BUT have different column names

# %%
def convert_to_datetime(df):
    df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
    df["Trip_Pickup_DateTime"] = pd.to_datetime(df["Trip_Pickup_DateTime"])
    df["pickup_datetime"] = pd.to_datetime(df["pickup_datetime"])

    df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])
    df["Trip_Dropoff_DateTime"] = pd.to_datetime(df["Trip_Dropoff_DateTime"])
    df["dropoff_datetime"] = pd.to_datetime(df["dropoff_datetime"])
    return df

# %%
yellow_taxi_ride_sample = convert_to_datetime(yellow_taxi_ride_sample)
yellow_taxi_ride_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DOLocationID           180000 non-null  float64
#  1   PULocationID           180000 non-null  float64
#  2   trip_distance          216000 non-null  float64
#  3   tip_amount             216000 non-null  float64
#  4   tpep_pickup_datetime   180000 non-null  datetime64[ns]
#  5   passenger_count        216000 non-null  float64
#  6   total_amount           216000 non-null  float64
#  7   tpep_dropoff_datetime  180000 non-null  datetime64[ns]
#  8   End_Lon                36000 non-null   float64
#  9   Trip_Pickup_DateTime   36000 non-null   datetime64[ns]
#  10  Trip_Distance          36000 non-null   float64
#  11  Passenger_Count        36000 non-null   float64
#  12  Start_Lat              36000 non-null   float64
#  13  Start_Lon              36000 non-null   float64
#  14  End_Lat                36000 non-null   float64
#  15  Total_Amt              36000 non-null   float64
#  16  Trip_Dropoff_DateTime  36000 non-null   datetime64[ns]
#  17  Tip_Amt                36000 non-null   float64
#  18  pickup_longitude       36000 non-null   float64
#  19  pickup_datetime        36000 non-null   datetime64[ns]
#  20  dropoff_datetime       36000 non-null   datetime64[ns]
#  21  pickup_latitude        36000 non-null   float64
#  22  dropoff_longitude      36000 non-null   float64
#  23  dropoff_latitude       36000 non-null   float64
# dtypes: datetime64[ns](6), float64(18)
# memory usage: 46.1 MB

# %%
def impute_pickup_datetime(row):
    if pd.notna(row['tpep_pickup_datetime']):
        return row['tpep_pickup_datetime']
    elif pd.notna(row['pickup_datetime']):
        return row['pickup_datetime']
    else:
        return row['Trip_Pickup_DateTime']
    
def impute_dropoff_datetime(row):
    if pd.notna(row['tpep_dropoff_datetime']):
        return row['tpep_dropoff_datetime']
    elif pd.notna(row['dropoff_datetime']):
        return row['dropoff_datetime']
    else:
        return row['Trip_Dropoff_DateTime']
    
def impute_trip_distance(row):
    if pd.notna(row['trip_distance']):
        return row['trip_distance']
    else:
        return row['Trip_Distance']
    
def impute_total_amount(row):
    if pd.notna(row['Total_Amt']):
        return row['Total_Amt']
    else:
        return row['total_amount']
    
def impute_pickup_lon(row):
    if pd.notna(row['pickup_longitude']):
        return row['pickup_longitude']
    else:
        return row['Start_Lon']
    
def impute_pickup_lat(row):
    if pd.notna(row['pickup_latitude']):
        return row['pickup_latitude']
    else:
        return row['Start_Lat']

def impute_dropoff_lon(row):
    if pd.notna(row['dropoff_longitude']):
        return row['dropoff_longitude']
    else:
        return row['End_Lon']

def impute_dropoff_lat(row):
    if pd.notna(row['dropoff_latitude']):
        return row['dropoff_latitude']
    else:
        return row['End_Lat']
    
def impute_passenger_count(row):
    if pd.notna(row['passenger_count']):
        return row['passenger_count']
    else:
        return row['Passenger_Count']
    
def impute_tip(row):
    if pd.notna(row['tip_amount']):
        return row['tip_amount']
    else:
        return row['Tip_Amt']

# %%
yellow_taxi_ride_sample['pickup_datetime'] = yellow_taxi_ride_sample.apply(impute_pickup_datetime, axis=1)
yellow_taxi_ride_sample['dropoff_datetime'] = yellow_taxi_ride_sample.apply(impute_dropoff_datetime, axis=1)
yellow_taxi_ride_sample['trip_distance'] = yellow_taxi_ride_sample.apply(impute_trip_distance, axis=1)
yellow_taxi_ride_sample['total_amount'] = yellow_taxi_ride_sample.apply(impute_total_amount, axis=1)
yellow_taxi_ride_sample['pickup_longitude'] = yellow_taxi_ride_sample.apply(impute_pickup_lon, axis=1)
yellow_taxi_ride_sample['pickup_latitude'] = yellow_taxi_ride_sample.apply(impute_pickup_lat, axis=1)
yellow_taxi_ride_sample['dropoff_longitude'] = yellow_taxi_ride_sample.apply(impute_dropoff_lon, axis=1)
yellow_taxi_ride_sample['dropoff_latitude'] = yellow_taxi_ride_sample.apply(impute_dropoff_lat, axis=1)
yellow_taxi_ride_sample['passenger_count'] = yellow_taxi_ride_sample.apply(impute_passenger_count, axis=1)
yellow_taxi_ride_sample['passenger_count'] = yellow_taxi_ride_sample['passenger_count'].astype(int)
yellow_taxi_ride_sample['tip_amount'] = yellow_taxi_ride_sample.apply(impute_tip, axis=1)
yellow_taxi_ride_sample = yellow_taxi_ride_sample.drop(columns=['tpep_pickup_datetime', 'Trip_Pickup_DateTime',\
                                                                'tpep_dropoff_datetime', 'Trip_Dropoff_DateTime',\
                                                                'Trip_Distance', 'Total_Amt',\
                                                                'Start_Lon', 'Start_Lat',\
                                                                'End_Lon', 'End_Lat', 'Passenger_Count', 'Tip_Amt'])
yellow_taxi_ride_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252000 entries, 0 to 251999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DOLocationID       180000 non-null  float64
#  1   PULocationID       180000 non-null  float64
#  2   trip_distance      252000 non-null  float64
#  3   tip_amount         252000 non-null  float64
#  4   passenger_count    252000 non-null  int64
#  5   total_amount       252000 non-null  float64
#  6   pickup_longitude   72000 non-null   float64
#  7   pickup_datetime    252000 non-null  datetime64[ns]
#  8   dropoff_datetime   252000 non-null  datetime64[ns]
#  9   pickup_latitude    72000 non-null   float64
#  10  dropoff_longitude  72000 non-null   float64
#  11  dropoff_latitude   72000 non-null   float64
# dtypes: datetime64[ns](2), float64(9), int64(1)
# memory usage: 23.1 MB

# %% [markdown]
# #### Deal with  `longitude` , `latitude`, and `Location ID` related problems

# %%
nan_rows_PUlon = yellow_taxi_ride_sample[yellow_taxi_ride_sample['pickup_longitude'].isnull() & yellow_taxi_ride_sample['PULocationID'].notnull()]
nan_rows_PUlat = yellow_taxi_ride_sample[yellow_taxi_ride_sample['pickup_latitude'].isnull() & yellow_taxi_ride_sample['PULocationID'].notnull()]
nan_rows_DOlon = yellow_taxi_ride_sample[yellow_taxi_ride_sample['dropoff_longitude'].isnull() & yellow_taxi_ride_sample['DOLocationID'].notnull()]
nan_rows_DOlat = yellow_taxi_ride_sample[yellow_taxi_ride_sample['dropoff_latitude'].isnull() & yellow_taxi_ride_sample['DOLocationID'].notnull()]
nan_rows_lon_lat = pd.concat([nan_rows_PUlon, nan_rows_PUlat, nan_rows_DOlon, nan_rows_DOlat], axis=1)
nan_rows_lon_lat = nan_rows_lon_lat.loc[:, ~nan_rows_lon_lat.columns.duplicated()]
nan_rows_lon_lat
# Out:
#         DOLocationID  PULocationID  trip_distance  tip_amount  \
# 0              141.0         113.0           4.32         0.0
# 1              162.0          48.0           1.40         0.0
# 2              237.0         237.0           0.85         1.5
# 3              237.0          79.0           3.00         0.0
# 4              114.0         261.0           1.87         2.0
# ...              ...           ...            ...         ...
# 248995         142.0          68.0           2.13         0.0
# 248996          74.0          24.0           2.20         0.0
# 248997         151.0         246.0           4.25         2.7
# 248998         164.0         100.0           0.80         0.0
# 248999         170.0          43.0           1.90         0.0
#
#         passenger_count  total_amount  pickup_longitude     pickup_datetime  \
# 0                     5          15.9               NaN 2011-07-08 23:15:00
# 1                     1           8.8               NaN 2011-07-20 19:22:24
# 2                     1           8.3               NaN 2011-07-26 18:18:00
# 3                     1          10.7               NaN 2011-07-01 21:33:28
# 4                     1           9.8               NaN 2011-07-02 16:04:00
# ...                 ...           ...               ...                 ...
# 248995                5           9.5               NaN 2014-03-20 20:32:00
# 248996                1          10.5               NaN 2014-03-09 22:07:27
# 248997                5          16.7               NaN 2014-03-23 03:14:00
# 248998                2           7.5               NaN 2014-03-17 16:11:18
# 248999                1          12.0               NaN 2014-03-12 19:43:37
#
#           dropoff_datetime  pickup_latitude  dropoff_longitude  \
# 0      2011-07-08 23:37:00              NaN                NaN
# 1      2011-07-20 19:32:33              NaN                NaN
# 2      2011-07-26 18:24:00              NaN                NaN
# 3      2011-07-01 21:44:42              NaN                NaN
# 4      2011-07-02 16:13:00              NaN                NaN
# ...                    ...              ...                ...
# 248995 2014-03-20 20:40:00              NaN                NaN
# 248996 2014-03-09 22:16:29              NaN                NaN
# 248997 2014-03-23 03:23:00              NaN                NaN
# 248998 2014-03-17 16:18:17              NaN                NaN
# 248999 2014-03-12 19:56:41              NaN                NaN
#
#         dropoff_latitude
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 248995               NaN
# 248996               NaN
# 248997               NaN
# 248998               NaN
# 248999               NaN
#
# [180000 rows x 12 columns]

# %%
rest_rows = yellow_taxi_ride_sample.loc[~yellow_taxi_ride_sample.index.isin(nan_rows_lon_lat.index)]
rows_lon_lat_exist = yellow_taxi_ride_sample[yellow_taxi_ride_sample['pickup_longitude'].notnull() & yellow_taxi_ride_sample['pickup_latitude'].notnull()]
print(f"Check 'rows_lon_lat_exist' and 'nan_rows_lon_lat' forms a partition of 'yellow_taxi_ride_sample': {(rest_rows.copy().drop(['PULocationID', 'DOLocationID'], axis=1)).equals(rows_lon_lat_exist.copy().drop(['PULocationID', 'DOLocationID'], axis=1))}")
# Out:
# Check 'rows_lon_lat_exist' and 'nan_rows_lon_lat' forms a partition of 'yellow_taxi_ride_sample': True

# %%
gdf_polygons = gpd.read_file('./taxi_zones/taxi_zones.shp')
gdf_polygons.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.770 256767.698, 1026495.593 ...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.310 144283.336, 936046.565 14...

# %%
gdf_polygons.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int64
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int64
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(2)
# memory usage: 14.5+ KB

# %%
def gdf_get_location(df):
    df = gdf_polygons.to_crs(4326)
    df['pickup_lon'] = df['geometry'].centroid.x
    df['pickup_lat'] = df['geometry'].centroid.y
    df['dropoff_lon'] = df['geometry'].centroid.x
    df['dropoff_lat'] = df['geometry'].centroid.y
    return df

# %%
gdf_polygons = gdf_get_location(gdf_polygons)
gdf_polygons.head()
# Out:
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/3985826996.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['pickup_lon'] = df['geometry'].centroid.x
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/3985826996.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['pickup_lat'] = df['geometry'].centroid.y
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/3985826996.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['dropoff_lon'] = df['geometry'].centroid.x
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/3985826996.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   df['dropoff_lat'] = df['geometry'].centroid.y
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry  \
# 0            EWR  POLYGON ((-74.18445 40.69500, -74.18449 40.695...
# 1         Queens  MULTIPOLYGON (((-73.82338 40.63899, -73.82277 ...
# 2          Bronx  POLYGON ((-73.84793 40.87134, -73.84725 40.870...
# 3      Manhattan  POLYGON ((-73.97177 40.72582, -73.97179 40.725...
# 4  Staten Island  POLYGON ((-74.17422 40.56257, -74.17349 40.562...
#
#    pickup_lon  pickup_lat  dropoff_lon  dropoff_lat
# 0  -74.174000   40.691831   -74.174000    40.691831
# 1  -73.831299   40.616745   -73.831299    40.616745
# 2  -73.847422   40.864474   -73.847422    40.864474
# 3  -73.976968   40.723752   -73.976968    40.723752
# 4  -74.188484   40.552659   -74.188484    40.552659

# %%
gdf_polygons.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OBJECTID     263 non-null    int64
#  1   Shape_Leng   263 non-null    float64
#  2   Shape_Area   263 non-null    float64
#  3   zone         263 non-null    object
#  4   LocationID   263 non-null    int64
#  5   borough      263 non-null    object
#  6   geometry     263 non-null    geometry
#  7   pickup_lon   263 non-null    float64
#  8   pickup_lat   263 non-null    float64
#  9   dropoff_lon  263 non-null    float64
#  10  dropoff_lat  263 non-null    float64
# dtypes: float64(6), geometry(1), int64(2), object(2)
# memory usage: 22.7+ KB

# %%
def merge_geo_df(geo_df, df):    
    # Merge nan_rows with geo_df to get the missing longtitude/latitude values
    # We use 'inner' merge to filter the rows with invalid location ID
    merged_nan_rows_PU = pd.merge(df, geo_df[['LocationID', 'pickup_lon', 'pickup_lat']],
                           left_on='PULocationID', right_on='LocationID', how='inner')
    merged_nan_rows = pd.merge(merged_nan_rows_PU, geo_df[['LocationID', 'dropoff_lon', 'dropoff_lat']],
                           left_on='DOLocationID', right_on='LocationID', how='inner')  
    return merged_nan_rows

# %%
nan_rows_lon_lat = merge_geo_df(gdf_polygons, nan_rows_lon_lat)
nan_rows_lon_lat['pickup_longitude'] = nan_rows_lon_lat['pickup_lon']
nan_rows_lon_lat['pickup_latitude'] = nan_rows_lon_lat['pickup_lat']
nan_rows_lon_lat['dropoff_longitude'] = nan_rows_lon_lat['dropoff_lon']
nan_rows_lon_lat['dropoff_latitude'] = nan_rows_lon_lat['dropoff_lat']
nan_rows_lon_lat = nan_rows_lon_lat.drop(columns=['pickup_lon', 'pickup_lat', 'dropoff_lon', 'dropoff_lat',\
                                                  'LocationID_x', 'LocationID_y'])
nan_rows_lon_lat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175493 entries, 0 to 175492
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DOLocationID       175493 non-null  float64
#  1   PULocationID       175493 non-null  float64
#  2   trip_distance      175493 non-null  float64
#  3   tip_amount         175493 non-null  float64
#  4   passenger_count    175493 non-null  int64
#  5   total_amount       175493 non-null  float64
#  6   pickup_longitude   175493 non-null  float64
#  7   pickup_datetime    175493 non-null  datetime64[ns]
#  8   dropoff_datetime   175493 non-null  datetime64[ns]
#  9   pickup_latitude    175493 non-null  float64
#  10  dropoff_longitude  175493 non-null  float64
#  11  dropoff_latitude   175493 non-null  float64
# dtypes: datetime64[ns](2), float64(9), int64(1)
# memory usage: 17.4 MB

# %%
yellow_taxi_ride_sample = pd.concat([nan_rows_lon_lat, rest_rows])
yellow_taxi_ride_sample = yellow_taxi_ride_sample.drop(columns=['PULocationID', 'DOLocationID'])
yellow_taxi_ride_sample
# Out:
#         trip_distance  tip_amount  passenger_count  total_amount  \
# 0                4.32        0.00                5         15.90
# 1                3.40        0.00                1         17.30
# 2                3.40        2.38                2         14.28
# 3                3.11        2.96                1         17.76
# 4                3.10        3.57                3         15.47
# ...               ...         ...              ...           ...
# 251995           1.00        0.00                1          6.50
# 251996           3.30        0.00                1         10.90
# 251997           2.00        0.00                4          7.70
# 251998           2.50        0.00                1          9.30
# 251999           2.50        0.00                1          8.50
#
#         pickup_longitude     pickup_datetime    dropoff_datetime  \
# 0             -73.994305 2011-07-08 23:15:00 2011-07-08 23:37:00
# 1             -73.994305 2015-08-14 08:49:06 2015-08-14 09:12:21
# 2             -73.994305 2011-06-01 21:18:40 2011-06-01 21:31:58
# 3             -73.994305 2015-01-25 20:39:21 2015-01-25 20:54:29
# 4             -73.994305 2012-08-31 21:40:39 2012-08-31 21:55:50
# ...                  ...                 ...                 ...
# 251995        -73.990944 2009-05-27 14:08:50 2009-05-27 14:18:26
# 251996        -73.949867 2009-05-22 14:17:46 2009-05-22 14:33:14
# 251997        -73.979666 2009-05-01 14:25:10 2009-05-01 14:34:42
# 251998        -73.980710 2009-05-10 13:43:46 2009-05-10 13:56:31
# 251999        -73.967279 2009-05-05 12:02:06 2009-05-05 12:11:07
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude
# 0             40.732579         -73.959635         40.766948
# 1             40.732579         -73.959635         40.766948
# 2             40.732579         -73.959635         40.766948
# 3             40.732579         -73.959635         40.766948
# 4             40.732579         -73.959635         40.766948
# ...                 ...                ...               ...
# 251995        40.730073         -73.993383         40.742037
# 251996        40.784443         -73.989309         40.771833
# 251997        40.771037         -73.969696         40.792058
# 251998        40.779881         -73.955583         40.770222
# 251999        40.803099         -73.947119         40.834849
#
# [247493 rows x 10 columns]

# %%
yellow_taxi_ride_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247493 entries, 0 to 251999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   trip_distance      247493 non-null  float64
#  1   tip_amount         247493 non-null  float64
#  2   passenger_count    247493 non-null  int64
#  3   total_amount       247493 non-null  float64
#  4   pickup_longitude   247493 non-null  float64
#  5   pickup_datetime    247493 non-null  datetime64[ns]
#  6   dropoff_datetime   247493 non-null  datetime64[ns]
#  7   pickup_latitude    247493 non-null  float64
#  8   dropoff_longitude  247493 non-null  float64
#  9   dropoff_latitude   247493 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1)
# memory usage: 20.8 MB

# %% [markdown]
# ### Data Preprocessing - Uber Data

# %%
uber_rides_sample.head()
# Out:
#                                     key  fare_amount          pickup_datetime  \
# 24238194    2015-05-07 19:52:06.0000003          7.5  2015-05-07 19:52:06 UTC
# 27835199    2009-07-17 20:04:56.0000002          7.7  2009-07-17 20:04:56 UTC
# 44984355   2009-08-24 21:45:00.00000061         12.9  2009-08-24 21:45:00 UTC
# 25894730    2009-06-26 08:22:21.0000001          5.3  2009-06-26 08:22:21 UTC
# 17610152  2014-08-28 17:47:00.000000188         16.0  2014-08-28 17:47:00 UTC
#
#           pickup_longitude  pickup_latitude  dropoff_longitude  \
# 24238194        -73.999817        40.738354         -73.999512
# 27835199        -73.994355        40.728225         -73.994710
# 44984355        -74.005043        40.740770         -73.962565
# 25894730        -73.976124        40.790844         -73.965316
# 17610152        -73.925023        40.744085         -73.973082
#
#           dropoff_latitude  passenger_count
# 24238194         40.723217                1
# 27835199         40.750325                1
# 44984355         40.772647                1
# 25894730         40.803349                3
# 17610152         40.761247                5

# %%
uber_rides_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200000 entries, 24238194 to 11951496
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                200000 non-null  object
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 13.7+ MB

# %%
#Check missing values
uber_rides_sample.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
uber_rides_sample['pickup_datetime'] = pd.to_datetime(uber_rides_sample['pickup_datetime'])
uber_rides_sample = uber_rides_sample.drop('key', axis=1) #Since Column 'key' has same values as Column 'pickup_datetime'
uber_rides_sample = uber_rides_sample.dropna() #Since there are very less missing values, we simply drop them
uber_rides_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 24238194 to 11951496
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_datetime    199999 non-null  datetime64[ns, UTC]
#  2   pickup_longitude   199999 non-null  float64
#  3   pickup_latitude    199999 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    199999 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1)
# memory usage: 12.2 MB

# %% [markdown]
# ### For Uber and Yellow Taxi data,
# #### remove out of region records

# %%
def remove_out_region(df):
    df = df[df['pickup_latitude'] >= 40.560445]
    df = df[df['pickup_latitude'] <= 40.908524]
    df = df[df['dropoff_latitude'] >= 40.560445]
    df = df[df['dropoff_latitude'] <= 40.908524]
    
    df = df[df['pickup_longitude'] >= -74.242330]
    df = df[df['pickup_longitude'] <= -73.71704]
    df = df[df['dropoff_longitude'] >= -74.242330]
    df = df[df['dropoff_longitude'] <= -73.71704]
    return df

# %%
yellow_taxi_ride_sample = remove_out_region(yellow_taxi_ride_sample)
uber_rides_sample = remove_out_region(remove_out_region(uber_rides_sample))

# %% [markdown]
# ####  Calculate trip distance between the pickup and dropoff location

# %%
def calculate_trip_distance(row):
    pickup_latitude = row['pickup_latitude']
    pickup_longitude = row['pickup_longitude']
    dropoff_latitude = row['dropoff_latitude']
    dropoff_longitude = row['dropoff_longitude']
    
    lat1, lon1, lat2, lon2 = map(math.radians, [pickup_latitude, pickup_longitude,  dropoff_latitude, dropoff_longitude])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    dist = math.sqrt(dlat**2 + dlon**2)
    
    R = 6371
    distance = dist * R
    return distance

# %%
yellow_taxi_ride_sample['distance_PD'] = yellow_taxi_ride_sample.apply(calculate_trip_distance, axis=1)
uber_rides_sample['distance_PD'] = uber_rides_sample.apply(calculate_trip_distance, axis=1)

# %% [markdown]
# #### Filter out zero distance

# %%
def remove_zero_distance(df):
    condition = df['distance_PD'] == 0
    df = df.drop(df[condition].index)
    return df

# %%
yellow_taxi_ride_sample = remove_zero_distance(yellow_taxi_ride_sample)
uber_rides_sample = remove_zero_distance(uber_rides_sample)

# %% [markdown]
# ### Cleaned Yellow Taxi Data sample and Uber Data sample

# %%
yellow_taxi_ride_sample
# Out:
#         trip_distance  tip_amount  passenger_count  total_amount  \
# 0                4.32        0.00                5         15.90
# 1                3.40        0.00                1         17.30
# 2                3.40        2.38                2         14.28
# 3                3.11        2.96                1         17.76
# 4                3.10        3.57                3         15.47
# ...               ...         ...              ...           ...
# 251995           1.00        0.00                1          6.50
# 251996           3.30        0.00                1         10.90
# 251997           2.00        0.00                4          7.70
# 251998           2.50        0.00                1          9.30
# 251999           2.50        0.00                1          8.50
#
#         pickup_longitude     pickup_datetime    dropoff_datetime  \
# 0             -73.994305 2011-07-08 23:15:00 2011-07-08 23:37:00
# 1             -73.994305 2015-08-14 08:49:06 2015-08-14 09:12:21
# 2             -73.994305 2011-06-01 21:18:40 2011-06-01 21:31:58
# 3             -73.994305 2015-01-25 20:39:21 2015-01-25 20:54:29
# 4             -73.994305 2012-08-31 21:40:39 2012-08-31 21:55:50
# ...                  ...                 ...                 ...
# 251995        -73.990944 2009-05-27 14:08:50 2009-05-27 14:18:26
# 251996        -73.949867 2009-05-22 14:17:46 2009-05-22 14:33:14
# 251997        -73.979666 2009-05-01 14:25:10 2009-05-01 14:34:42
# 251998        -73.980710 2009-05-10 13:43:46 2009-05-10 13:56:31
# 251999        -73.967279 2009-05-05 12:02:06 2009-05-05 12:11:07
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  distance_PD
# 0             40.732579         -73.959635         40.766948     5.428373
# 1             40.732579         -73.959635         40.766948     5.428373
# 2             40.732579         -73.959635         40.766948     5.428373
# 3             40.732579         -73.959635         40.766948     5.428373
# 4             40.732579         -73.959635         40.766948     5.428373
# ...                 ...                ...               ...          ...
# 251995        40.730073         -73.993383         40.742037     1.357699
# 251996        40.784443         -73.989309         40.771833     4.604441
# 251997        40.771037         -73.969696         40.792058     2.587005
# 251998        40.779881         -73.955583         40.770222     2.993318
# 251999        40.803099         -73.947119         40.834849     4.182006
#
# [231568 rows x 11 columns]

# %%
uber_rides_sample
# Out:
#           fare_amount           pickup_datetime  pickup_longitude  \
# 24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...               ...                       ...               ...
# 42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#           pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 24238194        40.738354         -73.999512         40.723217
# 27835199        40.728225         -73.994710         40.750325
# 44984355        40.740770         -73.962565         40.772647
# 25894730        40.790844         -73.965316         40.803349
# 17610152        40.744085         -73.973082         40.761247
# ...                   ...                ...               ...
# 42598914        40.739367         -73.986525         40.740297
# 16382965        40.736837         -74.006672         40.739620
# 27804658        40.756487         -73.858957         40.692588
# 20259894        40.725452         -73.983215         40.695415
# 11951496        40.720077         -73.985508         40.768793
#
#           passenger_count  distance_PD
# 24238194                1     1.683468
# 27835199                1     2.457725
# 44984355                1     5.905407
# 25894730                3     1.837874
# 17610152                5     5.674431
# ...                   ...          ...
# 42598914                1     0.118316
# 16382965                1     2.460268
# 27804658                2    15.814454
# 20259894                1     3.680636
# 11951496                1     5.418386
#
# [193514 rows x 8 columns]

# %% [markdown]
# ## Weather Data

# %%
path = './weather/'
all_files = glob.glob(path + "*.csv")
data_frames = []
for filename in all_files:
    df = pd.read_csv(filename)
    data_frames.append(df)
weather_data = pd.concat(data_frames, axis=0, ignore_index=True)
# Out:
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (7,8,9,10,17,18,42,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (8,9,17,18,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (17,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (10,41,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
# /var/folders/sg/pn3wv74s6vzfdmnrsyqsnz000000gn/T/ipykernel_62759/2213197053.py:5: DtypeWarning: Columns (8,9,10,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)

# %%
weather_data.head()
# Out:
#        STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  72505394728  2012-01-01T00:51:00  40.77898  -73.96925       42.7
# 1  72505394728  2012-01-01T01:51:00  40.77898  -73.96925       42.7
# 2  72505394728  2012-01-01T02:51:00  40.77898  -73.96925       42.7
# 3  72505394728  2012-01-01T03:51:00  40.77898  -73.96925       42.7
# 4  72505394728  2012-01-01T04:51:00  40.77898  -73.96925       42.7
#
#                           NAME REPORT_TYPE SOURCE HourlyAltimeterSetting  \
# 0  NY CITY CENTRAL PARK, NY US       AUTO       4                  30.05
# 1  NY CITY CENTRAL PARK, NY US       AUTO       4                  30.07
# 2  NY CITY CENTRAL PARK, NY US       AUTO       4                  30.08
# 3  NY CITY CENTRAL PARK, NY US       AUTO       4                  30.06
# 4  NY CITY CENTRAL PARK, NY US       AUTO       4                  30.07
#
#   HourlyDewPointTemperature  ... BackupDirection BackupDistance  \
# 0                        37  ...             ESE            0.5
# 1                        37  ...             ESE            0.5
# 2                        37  ...             ESE            0.5
# 3                        37  ...             ESE            0.5
# 4                        37  ...             ESE            0.5
#
#   BackupDistanceUnit BackupElements  BackupElevation  BackupEquipment  \
# 0                 mi           SNOW              NaN        SNOWBOARD
# 1                 mi           SNOW              NaN        SNOWBOARD
# 2                 mi           SNOW              NaN        SNOWBOARD
# 3                 mi           SNOW              NaN        SNOWBOARD
# 4                 mi           SNOW              NaN        SNOWBOARD
#
#   BackupLatitude BackupLongitude        BackupName WindEquipmentChangeDate
# 0            NaN             NaN  CENTRAL PARK ZOO              2006-09-18
# 1            NaN             NaN  CENTRAL PARK ZOO              2006-09-18
# 2            NaN             NaN  CENTRAL PARK ZOO              2006-09-18
# 3            NaN             NaN  CENTRAL PARK ZOO              2006-09-18
# 4            NaN             NaN  CENTRAL PARK ZOO              2006-09-18
#
# [5 rows x 123 columns]

# %% [markdown]
# ### Hourly Weather Dataset

# %%
weather_data_hourly = weather_data.iloc[:, 1:4].join(weather_data.iloc[:, 8:24])
weather_data_hourly.head()
# Out:
#                   DATE  LATITUDE  LONGITUDE HourlyAltimeterSetting  \
# 0  2012-01-01T00:51:00  40.77898  -73.96925                  30.05
# 1  2012-01-01T01:51:00  40.77898  -73.96925                  30.07
# 2  2012-01-01T02:51:00  40.77898  -73.96925                  30.08
# 3  2012-01-01T03:51:00  40.77898  -73.96925                  30.06
# 4  2012-01-01T04:51:00  40.77898  -73.96925                  30.07
#
#   HourlyDewPointTemperature HourlyDryBulbTemperature HourlyPrecipitation  \
# 0                        37                       46                 NaN
# 1                        37                       45                 NaN
# 2                        37                       45                 NaN
# 3                        37                       45                 NaN
# 4                        37                       43                 NaN
#
#   HourlyPresentWeatherType HourlyPressureChange  HourlyPressureTendency  \
# 0                      NaN                -0.05                     1.0
# 1                      NaN                  NaN                     NaN
# 2                      NaN                  NaN                     NaN
# 3                      NaN                -0.01                     0.0
# 4                      NaN                  NaN                     NaN
#
#    HourlyRelativeHumidity HourlySkyConditions HourlySeaLevelPressure  \
# 0                    71.0                 NaN                  30.03
# 1                    76.0                 NaN                  30.04
# 2                    76.0                 NaN                  30.05
# 3                    76.0                 NaN                  30.04
# 4                    81.0                 NaN                  30.05
#
#   HourlyStationPressure HourlyVisibility  HourlyWetBulbTemperature  \
# 0                   NaN            10.00                       NaN
# 1                   NaN            10.00                       NaN
# 2                   NaN            10.00                       NaN
# 3                   NaN            10.00                       NaN
# 4                   NaN            10.00                       NaN
#
#   HourlyWindDirection  HourlyWindGustSpeed  HourlyWindSpeed
# 0                 VRB                  NaN              6.0
# 1                 VRB                  NaN              7.0
# 2                 260                  NaN              6.0
# 3                 290                  NaN              5.0
# 4                 000                  NaN              0.0

# %%
weather_data_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77972 entries, 0 to 77971
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DATE                       77972 non-null  object
#  1   LATITUDE                   77972 non-null  float64
#  2   LONGITUDE                  77972 non-null  float64
#  3   HourlyAltimeterSetting     75531 non-null  object
#  4   HourlyDewPointTemperature  76017 non-null  object
#  5   HourlyDryBulbTemperature   76028 non-null  object
#  6   HourlyPrecipitation        39961 non-null  object
#  7   HourlyPresentWeatherType   15357 non-null  object
#  8   HourlyPressureChange       19844 non-null  object
#  9   HourlyPressureTendency     19844 non-null  float64
#  10  HourlyRelativeHumidity     76016 non-null  float64
#  11  HourlySkyConditions        36313 non-null  object
#  12  HourlySeaLevelPressure     59592 non-null  object
#  13  HourlyStationPressure      37569 non-null  object
#  14  HourlyVisibility           75375 non-null  object
#  15  HourlyWetBulbTemperature   37564 non-null  float64
#  16  HourlyWindDirection        73714 non-null  object
#  17  HourlyWindGustSpeed        14027 non-null  float64
#  18  HourlyWindSpeed            73713 non-null  float64
# dtypes: float64(7), object(12)
# memory usage: 11.3+ MB

# %%
#Check missing values
weather_data_hourly.isnull().sum()
# Out:
# DATE                             0
# LATITUDE                         0
# LONGITUDE                        0
# HourlyAltimeterSetting        2441
# HourlyDewPointTemperature     1955
# HourlyDryBulbTemperature      1944
# HourlyPrecipitation          38011
# HourlyPresentWeatherType     62615
# HourlyPressureChange         58128
# HourlyPressureTendency       58128
# HourlyRelativeHumidity        1956
# HourlySkyConditions          41659
# HourlySeaLevelPressure       18380
# HourlyStationPressure        40403
# HourlyVisibility              2597
# HourlyWetBulbTemperature     40408
# HourlyWindDirection           4258
# HourlyWindGustSpeed          63945
# HourlyWindSpeed               4259
# dtype: int64

# %% [markdown]
# #### Fills missing values with 0, mean or mode

# %%
weather_data_hourly['HourlyStationPressure'] = weather_data_hourly['HourlyStationPressure'].str.replace('s', '')
weather_data_hourly['HourlyStationPressure'] = weather_data_hourly['HourlyStationPressure'].astype(float)

weather_data_hourly['HourlyPrecipitation'].fillna(0, inplace=True)
weather_data_hourly['HourlyPresentWeatherType'].fillna(weather_data_hourly['HourlyPresentWeatherType'].mode()[0], inplace=True)
weather_data_hourly['HourlyPressureTendency'].fillna(weather_data_hourly['HourlyPressureTendency'].mean(), inplace=True)
weather_data_hourly['HourlySkyConditions'].fillna(weather_data_hourly['HourlySkyConditions'].mode()[0], inplace=True)
weather_data_hourly['HourlyStationPressure'].fillna(weather_data_hourly['HourlyStationPressure'].mean(), inplace=True)
weather_data_hourly['HourlyWetBulbTemperature'].fillna(weather_data_hourly['HourlyWetBulbTemperature'].mean(), inplace=True)
weather_data_hourly['HourlyWindGustSpeed'].fillna(weather_data_hourly['HourlyWindGustSpeed'].mean(), inplace=True)

# %% [markdown]
# #### Fills missing values with the last known value in the same column

# %%
ffill_cols = ['HourlyAltimeterSetting', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature', 'HourlyRelativeHumidity',
              'HourlyVisibility', 'HourlyWindDirection', 'HourlyWindSpeed', 'HourlyPressureChange']
weather_data_hourly[ffill_cols] = weather_data_hourly[ffill_cols].fillna(method='ffill')

# %% [markdown]
# #### Fills missing values with the next known value in the same column

# %%
bfill_cols = ['HourlySeaLevelPressure']
weather_data_hourly[bfill_cols] = weather_data_hourly[bfill_cols].fillna(method='bfill')

# %% [markdown]
# ### Cleaned Hourly Weather Dataset

# %%
weather_data_hourly
# Out:
#                       DATE  LATITUDE  LONGITUDE HourlyAltimeterSetting  \
# 0      2012-01-01T00:51:00  40.77898  -73.96925                  30.05
# 1      2012-01-01T01:51:00  40.77898  -73.96925                  30.07
# 2      2012-01-01T02:51:00  40.77898  -73.96925                  30.08
# 3      2012-01-01T03:51:00  40.77898  -73.96925                  30.06
# 4      2012-01-01T04:51:00  40.77898  -73.96925                  30.07
# ...                    ...       ...        ...                    ...
# 77967  2010-12-31T19:51:00  40.77898  -73.96925                  30.18
# 77968  2010-12-31T20:51:00  40.77898  -73.96925                  30.18
# 77969  2010-12-31T21:51:00  40.77898  -73.96925                  30.19
# 77970  2010-12-31T22:51:00  40.77898  -73.96925                  30.17
# 77971  2010-12-31T23:51:00  40.77898  -73.96925                  30.15
#
#       HourlyDewPointTemperature HourlyDryBulbTemperature HourlyPrecipitation  \
# 0                            37                       46                   0
# 1                            37                       45                   0
# 2                            37                       45                   0
# 3                            37                       45                   0
# 4                            37                       43                   0
# ...                         ...                      ...                 ...
# 77967                      28.0                     43.0                   0
# 77968                      28.0                     43.0                   0
# 77969                      28.0                     43.0                   0
# 77970                      28.0                     43.0                   0
# 77971                      28.0                     43.0                   0
#
#       HourlyPresentWeatherType HourlyPressureChange  HourlyPressureTendency  \
# 0                        |RA |                -0.05                1.000000
# 1                        |RA |                -0.05                4.266126
# 2                        |RA |                -0.05                4.266126
# 3                        |RA |                -0.01                0.000000
# 4                        |RA |                -0.01                4.266126
# ...                        ...                  ...                     ...
# 77967                    |RA |                -0.03                4.266126
# 77968                    |RA |                -0.03                4.266126
# 77969                    |RA |                 0.01                5.000000
# 77970                    |RA |                 0.01                4.266126
# 77971                    |RA |                 0.01                4.266126
#
#        HourlyRelativeHumidity HourlySkyConditions HourlySeaLevelPressure  \
# 0                        71.0              CLR:00                  30.03
# 1                        76.0              CLR:00                  30.04
# 2                        76.0              CLR:00                  30.05
# 3                        76.0              CLR:00                  30.04
# 4                        81.0              CLR:00                  30.05
# ...                       ...                 ...                    ...
# 77967                    57.0              CLR:00                  30.16
# 77968                    57.0              CLR:00                  30.16
# 77969                    57.0              CLR:00                  30.16
# 77970                    57.0              CLR:00                  30.14
# 77971                    57.0              CLR:00                  30.13
#
#        HourlyStationPressure HourlyVisibility  HourlyWetBulbTemperature  \
# 0                  29.865065            10.00                 49.521217
# 1                  29.865065            10.00                 49.521217
# 2                  29.865065            10.00                 49.521217
# 3                  29.865065            10.00                 49.521217
# 4                  29.865065            10.00                 49.521217
# ...                      ...              ...                       ...
# 77967              29.865065              7.0                 49.521217
# 77968              29.865065              7.0                 49.521217
# 77969              29.865065              7.0                 49.521217
# 77970              29.865065              7.0                 49.521217
# 77971              29.865065              7.0                 49.521217
#
#       HourlyWindDirection  HourlyWindGustSpeed  HourlyWindSpeed
# 0                     VRB            21.127112              6.0
# 1                     VRB            21.127112              7.0
# 2                     260            21.127112              6.0
# 3                     290            21.127112              5.0
# 4                     000            21.127112              0.0
# ...                   ...                  ...              ...
# 77967                 VRB            21.127112              5.0
# 77968                 VRB            21.127112              7.0
# 77969                 VRB            21.127112              7.0
# 77970                 240            21.127112              6.0
# 77971                 240            21.127112              7.0
#
# [77972 rows x 19 columns]

# %%
weather_data_hourly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77972 entries, 0 to 77971
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DATE                       77972 non-null  object
#  1   LATITUDE                   77972 non-null  float64
#  2   LONGITUDE                  77972 non-null  float64
#  3   HourlyAltimeterSetting     77972 non-null  object
#  4   HourlyDewPointTemperature  77972 non-null  object
#  5   HourlyDryBulbTemperature   77972 non-null  object
#  6   HourlyPrecipitation        77972 non-null  object
#  7   HourlyPresentWeatherType   77972 non-null  object
#  8   HourlyPressureChange       77972 non-null  object
#  9   HourlyPressureTendency     77972 non-null  float64
#  10  HourlyRelativeHumidity     77972 non-null  float64
#  11  HourlySkyConditions        77972 non-null  object
#  12  HourlySeaLevelPressure     77972 non-null  object
#  13  HourlyStationPressure      77972 non-null  float64
#  14  HourlyVisibility           77972 non-null  object
#  15  HourlyWetBulbTemperature   77972 non-null  float64
#  16  HourlyWindDirection        77972 non-null  object
#  17  HourlyWindGustSpeed        77972 non-null  float64
#  18  HourlyWindSpeed            77972 non-null  float64
# dtypes: float64(8), object(11)
# memory usage: 11.3+ MB

# %% [markdown]
# ### Daily Weather Dataset

# %%
weather_data_daily = weather_data.iloc[:, 24:46]
weather_data_daily = pd.concat([weather_data_hourly, weather_data_daily], axis=1)
weather_data_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77972 entries, 0 to 77971
# Data columns (total 41 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   DATE                                        77972 non-null  object
#  1   LATITUDE                                    77972 non-null  float64
#  2   LONGITUDE                                   77972 non-null  float64
#  3   HourlyAltimeterSetting                      77972 non-null  object
#  4   HourlyDewPointTemperature                   77972 non-null  object
#  5   HourlyDryBulbTemperature                    77972 non-null  object
#  6   HourlyPrecipitation                         77972 non-null  object
#  7   HourlyPresentWeatherType                    77972 non-null  object
#  8   HourlyPressureChange                        77972 non-null  object
#  9   HourlyPressureTendency                      77972 non-null  float64
#  10  HourlyRelativeHumidity                      77972 non-null  float64
#  11  HourlySkyConditions                         77972 non-null  object
#  12  HourlySeaLevelPressure                      77972 non-null  object
#  13  HourlyStationPressure                       77972 non-null  float64
#  14  HourlyVisibility                            77972 non-null  object
#  15  HourlyWetBulbTemperature                    77972 non-null  float64
#  16  HourlyWindDirection                         77972 non-null  object
#  17  HourlyWindGustSpeed                         77972 non-null  float64
#  18  HourlyWindSpeed                             77972 non-null  float64
#  19  Sunrise                                     1826 non-null   float64
#  20  Sunset                                      1826 non-null   float64
#  21  DailyAverageDewPointTemperature             1169 non-null   float64
#  22  DailyAverageDryBulbTemperature              1249 non-null   float64
#  23  DailyAverageRelativeHumidity                1184 non-null   float64
#  24  DailyAverageSeaLevelPressure                1165 non-null   float64
#  25  DailyAverageStationPressure                 1228 non-null   float64
#  26  DailyAverageWetBulbTemperature              1169 non-null   float64
#  27  DailyAverageWindSpeed                       1246 non-null   float64
#  28  DailyCoolingDegreeDays                      1249 non-null   float64
#  29  DailyDepartureFromNormalAverageTemperature  1249 non-null   float64
#  30  DailyHeatingDegreeDays                      1249 non-null   float64
#  31  DailyMaximumDryBulbTemperature              1249 non-null   float64
#  32  DailyMinimumDryBulbTemperature              1249 non-null   float64
#  33  DailyPeakWindDirection                      1239 non-null   float64
#  34  DailyPeakWindSpeed                          1242 non-null   float64
#  35  DailyPrecipitation                          1249 non-null   object
#  36  DailySnowDepth                              1249 non-null   object
#  37  DailySnowfall                               1249 non-null   object
#  38  DailySustainedWindDirection                 1247 non-null   float64
#  39  DailySustainedWindSpeed                     1249 non-null   float64
#  40  DailyWeather                                1109 non-null   object
# dtypes: float64(26), object(15)
# memory usage: 24.4+ MB

# %%
weather_data_daily.head()
# Out:
#                   DATE  LATITUDE  LONGITUDE HourlyAltimeterSetting  \
# 0  2012-01-01T00:51:00  40.77898  -73.96925                  30.05
# 1  2012-01-01T01:51:00  40.77898  -73.96925                  30.07
# 2  2012-01-01T02:51:00  40.77898  -73.96925                  30.08
# 3  2012-01-01T03:51:00  40.77898  -73.96925                  30.06
# 4  2012-01-01T04:51:00  40.77898  -73.96925                  30.07
#
#   HourlyDewPointTemperature HourlyDryBulbTemperature HourlyPrecipitation  \
# 0                        37                       46                   0
# 1                        37                       45                   0
# 2                        37                       45                   0
# 3                        37                       45                   0
# 4                        37                       43                   0
#
#   HourlyPresentWeatherType HourlyPressureChange  HourlyPressureTendency  ...  \
# 0                    |RA |                -0.05                1.000000  ...
# 1                    |RA |                -0.05                4.266126  ...
# 2                    |RA |                -0.05                4.266126  ...
# 3                    |RA |                -0.01                0.000000  ...
# 4                    |RA |                -0.01                4.266126  ...
#
#    DailyMaximumDryBulbTemperature DailyMinimumDryBulbTemperature  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   DailyPeakWindDirection  DailyPeakWindSpeed DailyPrecipitation  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
#
#    DailySnowDepth DailySnowfall  DailySustainedWindDirection  \
# 0             NaN           NaN                          NaN
# 1             NaN           NaN                          NaN
# 2             NaN           NaN                          NaN
# 3             NaN           NaN                          NaN
# 4             NaN           NaN                          NaN
#
#    DailySustainedWindSpeed  DailyWeather
# 0                      NaN           NaN
# 1                      NaN           NaN
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4                      NaN           NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# # Part 2: Storing Data

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///project.db', echo=True)
# Base.metadata.create_all(engine)

# %% [markdown]
# ### Four tables

# %%
import sqlite3
connection = sqlite3.connect("project.db")

#Yellow Taxi trips
with connection:
    connection.execute(
        """
        CREATE TABLE IF NOT EXISTS yellow_taxi_ride (
            id INTEGER PRIMARY KEY,
            trip_distance REAL,
            passenger_count INTEGER,
            total_amount REAL,
            dropoff_datetime DATETIME,
            pickup_longitude REAL,
            pickup_latitude REAL,
            dropoff_latitude REAL,
            dropoff_longitude REAL,
            pickup_datetime DATETIME
        );
        """
    )

#Uber trips
with connection:
    connection.execute(
        """
        CREATE TABLE IF NOT EXISTS uber_rides (
            id INTEGER PRIMARY KEY,
            fare_amount REAL,
            pickup_datetime DATETIME,
            pickup_longitude REAL,
            pickup_latitude REAL,
            dropoff_longitude REAL,
            dropoff_latitude REAL,
            passenger_count INTEGER,
            trip_distance REAL
        );
        """
    )

# %%
with engine.connect() as conn:
    yellow_taxi_ride_sample.to_sql('yellow_taxi_ride', conn, if_exists='replace', index=False)
    uber_rides_sample.to_sql('uber_rides', conn, if_exists='replace', index=False)
# Out:
# 2023-04-30 00:30:10,299 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-30 00:30:10,299 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("yellow_taxi_ride")
# 2023-04-30 00:30:10,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,300 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("yellow_taxi_ride")
# 2023-04-30 00:30:10,300 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,301 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-04-30 00:30:10,301 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,302 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_temp_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-04-30 00:30:10,303 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,303 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("yellow_taxi_ride")
# 2023-04-30 00:30:10,303 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,304 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:10,304 INFO sqlalchemy.engine.Engine [raw sql] ('yellow_taxi_ride',)
# 2023-04-30 00:30:10,305 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,305 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,305 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,306 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,306 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:10,307 INFO sqlalchemy.engine.Engine [raw sql] ('yellow_taxi_ride',)
# 2023-04-30 00:30:10,308 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,308 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,308 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,309 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,309 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("yellow_taxi_ride")
# 2023-04-30 00:30:10,309 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,309 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,310 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,310 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("yellow_taxi_ride")
# 2023-04-30 00:30:10,310 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,310 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("yellow_taxi_ride")
# 2023-04-30 00:30:10,311 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:10,311 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:10,311 INFO sqlalchemy.engine.Engine [raw sql] ('yellow_taxi_ride',)
# 2023-04-30 00:30:10,313 INFO sqlalchemy.engine.Engine
# DROP TABLE yellow_taxi_ride
# 2023-04-30 00:30:10,313 INFO sqlalchemy.engine.Engine [no key 0.00028s] ()
# 2023-04-30 00:30:10,314 INFO sqlalchemy.engine.Engine
# CREATE TABLE yellow_taxi_ride (
# 	trip_distance FLOAT,
# 	tip_amount FLOAT,
# 	passenger_count BIGINT,
# 	total_amount FLOAT,
# 	pickup_longitude FLOAT,
# 	pickup_datetime DATETIME,
# 	dropoff_datetime DATETIME,
# 	pickup_latitude FLOAT,
# 	dropoff_longitude FLOAT,
# 	dropoff_latitude FLOAT,
# 	"distance_PD" FLOAT
# )
#
#
# 2023-04-30 00:30:10,315 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2023-04-30 00:30:11,791 INFO sqlalchemy.engine.Engine INSERT INTO yellow_taxi_ride (trip_distance, tip_amount, passenger_count, total_amount, pickup_longitude, pickup_datetime, dropoff_datetime, pickup_latitude, dropoff_longitude, dropoff_latitude, "distance_PD") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-04-30 00:30:11,792 INFO sqlalchemy.engine.Engine [generated in 1.19135s] [(4.32, 0.0, 5, 15.9, -73.99430477051168, '2011-07-08 23:15:00.000000', '2011-07-08 23:37:00.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.4, 0.0, 1, 17.3, -73.99430477051168, '2015-08-14 08:49:06.000000', '2015-08-14 09:12:21.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.4, 2.38, 2, 14.28, -73.99430477051168, '2011-06-01 21:18:40.000000', '2011-06-01 21:31:58.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.11, 2.96, 1, 17.76, -73.99430477051168, '2015-01-25 20:39:21.000000', '2015-01-25 20:54:29.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.1, 3.57, 3, 15.47, -73.99430477051168, '2012-08-31 21:40:39.000000', '2012-08-31 21:55:50.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.3, 2.85, 1, 17.15, -73.99430477051168, '2015-03-20 22:34:04.000000', '2015-03-20 22:49:05.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (3.6, 2.0, 1, 16.5, -73.99430477051168, '2013-03-02 13:42:18.000000', '2013-03-02 13:58:01.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589), (4.4, 3.0, 1, 16.8, -73.99430477051168, '2011-09-10 11:53:19.000000', '2011-09-10 12:10:32.000000', 40.73257907302703, -73.9596347414917, 40.766948216383234, 5.428372925934589)  ... displaying 10 of 231568 total bound parameter sets ...  (2.5, 0.0, 1, 9.3, -73.98071, '2009-05-10 13:43:46.000000', '2009-05-10 13:56:31.000000', 40.779881, -73.955583, 40.770222, 2.9933178786816104), (2.5, 0.0, 1, 8.5, -73.967279, '2009-05-05 12:02:06.000000', '2009-05-05 12:11:07.000000', 40.803099, -73.947119, 40.834849, 4.182005712644709)]
# 2023-04-30 00:30:12,019 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("uber_rides")
# 2023-04-30 00:30:12,020 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,020 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("uber_rides")
# 2023-04-30 00:30:12,021 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,021 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-04-30 00:30:12,021 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,022 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_temp_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-04-30 00:30:12,022 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,022 INFO sqlalchemy.engine.Engine PRAGMA main.table_xinfo("uber_rides")
# 2023-04-30 00:30:12,023 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,023 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:12,023 INFO sqlalchemy.engine.Engine [raw sql] ('uber_rides',)
# 2023-04-30 00:30:12,024 INFO sqlalchemy.engine.Engine PRAGMA main.foreign_key_list("uber_rides")
# 2023-04-30 00:30:12,024 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,024 INFO sqlalchemy.engine.Engine PRAGMA temp.foreign_key_list("uber_rides")
# 2023-04-30 00:30:12,025 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,025 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:12,025 INFO sqlalchemy.engine.Engine [raw sql] ('uber_rides',)
# 2023-04-30 00:30:12,025 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("uber_rides")
# 2023-04-30 00:30:12,026 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,026 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("uber_rides")
# 2023-04-30 00:30:12,026 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,027 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("uber_rides")
# 2023-04-30 00:30:12,027 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,027 INFO sqlalchemy.engine.Engine PRAGMA main.index_list("uber_rides")
# 2023-04-30 00:30:12,028 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,028 INFO sqlalchemy.engine.Engine PRAGMA temp.index_list("uber_rides")
# 2023-04-30 00:30:12,028 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,028 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("uber_rides")
# 2023-04-30 00:30:12,029 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,029 INFO sqlalchemy.engine.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type in ('table', 'view')
# 2023-04-30 00:30:12,029 INFO sqlalchemy.engine.Engine [raw sql] ('uber_rides',)
# 2023-04-30 00:30:12,030 INFO sqlalchemy.engine.Engine
# DROP TABLE uber_rides
# 2023-04-30 00:30:12,030 INFO sqlalchemy.engine.Engine [no key 0.00026s] ()
# 2023-04-30 00:30:12,031 INFO sqlalchemy.engine.Engine
# CREATE TABLE uber_rides (
# 	fare_amount FLOAT,
# 	pickup_datetime TIMESTAMP,
# 	pickup_longitude FLOAT,
# 	pickup_latitude FLOAT,
# 	dropoff_longitude FLOAT,
# 	dropoff_latitude FLOAT,
# 	passenger_count BIGINT,
# 	"distance_PD" FLOAT
# )
#
#
# 2023-04-30 00:30:12,031 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2023-04-30 00:30:12,830 INFO sqlalchemy.engine.Engine INSERT INTO uber_rides (fare_amount, pickup_datetime, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, "distance_PD") VALUES (?, ?, ?, ?, ?, ?, ?, ?)
# 2023-04-30 00:30:12,831 INFO sqlalchemy.engine.Engine [generated in 0.66271s] [(7.5, '2015-05-07 19:52:06.000000', -73.99981689453125, 40.73835372924805, -73.99951171875, 40.72321701049805, 1, 1.683468372889847), (7.7, '2009-07-17 20:04:56.000000', -73.994355, 40.728225, -73.99471, 40.750325, 1, 2.4577249023006513), (12.9, '2009-08-24 21:45:00.000000', -74.005043, 40.74077, -73.962565, 40.772647, 1, 5.905407110501063), (5.3, '2009-06-26 08:22:21.000000', -73.976124, 40.790844, -73.965316, 40.803349, 3, 1.837873830108156), (16.0, '2014-08-28 17:47:00.000000', -73.925023, 40.744085, -73.97308199999999, 40.761247, 5, 5.674430534202403), (24.5, '2014-10-12 07:04:00.000000', -73.96144699999999, 40.693965000000006, -73.871195, 40.774297, 5, 13.43511463520242), (9.7, '2012-02-17 09:32:00.000000', -73.975187, 40.745767, -74.00272, 40.743537, 1, 3.0715552913805273), (12.5, '2012-03-29 19:06:00.000000', -74.001065, 40.741787, -73.96304, 40.775012, 1, 5.614849727048812)  ... displaying 10 of 193514 total bound parameter sets ...  (14.5, '2015-05-20 14:56:25.000000', -73.99712371826173, 40.7254524230957, -73.98321533203125, 40.69541549682617, 1, 3.6806363024005675), (14.1, '2010-05-15 04:08:00.000000', -73.98439499999999, 40.720077, -73.985508, 40.768793, 1, 5.418385615449128)]
# 2023-04-30 00:30:12,989 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
from sqlalchemy import inspect
inspector = inspect(engine)
with open('schema.sql', 'w') as f:
    for table_name in inspector.get_table_names():
        schema_name = inspector.get_schema_item(table_name, 'schema')
        table_columns = inspector.get_columns(table_name)
        create_table_query = f"CREATE TABLE IF NOT EXISTS {schema_name}.{table_name} (\n"
        for column in table_columns:
            col_name = column['name']
            col_type = column['type']
            create_table_query += f"\t{col_name} {col_type},\n"
        create_table_query = create_table_query.rstrip(',\n') + "\n);"
        f.write(create_table_query + "\n\n")
# Out:
# 2023-04-30 00:30:12,995 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-04-30 00:30:12,995 INFO sqlalchemy.engine.Engine SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite~_%' ESCAPE '~' ORDER BY name
# 2023-04-30 00:30:12,995 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-04-30 00:30:12,996 INFO sqlalchemy.engine.Engine ROLLBACK
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 5
#       3 with open('schema.sql', 'w') as f:
#       4     for table_name in inspector.get_table_names():
# ----> 5         schema_name = inspector.get_schema_item(table_name, 'schema')
#       6         table_columns = inspector.get_columns(table_name)
#       7         create_table_query = f"CREATE TABLE IF NOT EXISTS {schema_name}.{table_name} (\n"
#
# AttributeError: 'Inspector' object has no attribute 'get_schema_item'

# %% [markdown]
# # Part 3: Understanding Data

# %% [markdown]
# # Part 4: Visualizing Data
